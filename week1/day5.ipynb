# %% [markdown]
# # A full business solution
#
# ## Now we will take our project from Day 1 to the next level
#
# ### BUSINESS CHALLENGE:
#
# Create a product that builds a Brochure for a company to be used for prospective clients, investors and potential recruits.
#
# We will be provided a company name and their primary website.
#
# See the end of this notebook for examples of real-world business applications.
#
# And remember: I'm always available if you have problems or ideas! Please do reach out.

# %%
# imports
# If these fail, please check you're running from an 'activated' environment with (llms) in the command prompt

import os
import requests
import json
from typing import List
from dotenv import load_dotenv
from bs4 import BeautifulSoup
from IPython.display import Markdown, display, update_display
from openai import OpenAI

# %%
# Initialize and constants

load_dotenv(override=True)
api_key = os.getenv('OPENAI_API_KEY')
print(api_key)
if api_key and api_key.startswith('sk-proj-') and len(api_key)>10:
    print("API key looks good so far")
else:
    print("There might be a problem with your API key? Please visit the troubleshooting notebook!")
    
MODEL = 'gpt-4o-mini'
openai = OpenAI()
# Out:
# sk-fqwpfn5auItFtCyqc329RUT0naKEaOPDP9SDs_oELRT3BlbkFJeO_eT-3eluAKMhxjpJZYou4dSAHXSLmdzjNA8MYU4A
# There might be a problem with your API key? Please visit the troubleshooting notebook!

# %%
# A class to represent a Webpage

# Some websites need you to use proper headers when fetching them:
headers = {
 "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/117.0.0.0 Safari/537.36"
}

class Website:
    """
    A utility class to represent a Website that we have scraped, now with links
    """

    def __init__(self, url):
        self.url = url
        response = requests.get(url, headers=headers)
        self.body = response.content
        soup = BeautifulSoup(self.body, 'html.parser')
        self.title = soup.title.string if soup.title else "No title found"
        if soup.body:
            for irrelevant in soup.body(["script", "style", "img", "input"]):
                irrelevant.decompose()
            self.text = soup.body.get_text(separator="\n", strip=True)
        else:
            self.text = ""
        links = [link.get('href') for link in soup.find_all('a')]
        self.links = [link for link in links if link]

    def get_contents(self):
        return f"Webpage Title:\n{self.title}\nWebpage Contents:\n{self.text}\n\n"

# %%
ed = Website("https://edwarddonner.com")
ed.links
# Out:
# ['https://edwarddonner.com/',
#  'https://edwarddonner.com/connect-four/',
#  'https://edwarddonner.com/outsmart/',
#  'https://edwarddonner.com/about-me-and-about-nebula/',
#  'https://edwarddonner.com/posts/',
#  'https://edwarddonner.com/',
#  'https://news.ycombinator.com',
#  'https://nebula.io/?utm_source=ed&utm_medium=referral',
#  'https://www.prnewswire.com/news-releases/wynden-stark-group-acquires-nyc-venture-backed-tech-startup-untapt-301269512.html',
#  'https://patents.google.com/patent/US20210049536A1/',
#  'https://www.linkedin.com/in/eddonner/',
#  'https://edwarddonner.com/2025/04/21/the-complete-agentic-ai-engineering-course/',
#  'https://edwarddonner.com/2025/04/21/the-complete-agentic-ai-engineering-course/',
#  'https://edwarddonner.com/2025/01/23/llm-workshop-hands-on-with-agents-resources/',
#  'https://edwarddonner.com/2025/01/23/llm-workshop-hands-on-with-agents-resources/',
#  'https://edwarddonner.com/2024/12/21/llm-resources-superdatascience/',
#  'https://edwarddonner.com/2024/12/21/llm-resources-superdatascience/',
#  'https://edwarddonner.com/2024/11/13/llm-engineering-resources/',
#  'https://edwarddonner.com/2024/11/13/llm-engineering-resources/',
#  'https://edwarddonner.com/',
#  'https://edwarddonner.com/connect-four/',
#  'https://edwarddonner.com/outsmart/',
#  'https://edwarddonner.com/about-me-and-about-nebula/',
#  'https://edwarddonner.com/posts/',
#  'mailto:hello@mygroovydomain.com',
#  'https://www.linkedin.com/in/eddonner/',
#  'https://twitter.com/edwarddonner',
#  'https://www.facebook.com/edward.donner.52']

# %% [markdown]
# ## First step: Have GPT-4o-mini figure out which links are relevant
#
# ### Use a call to gpt-4o-mini to read the links on a webpage, and respond in structured JSON.
# It should decide which links are relevant, and replace relative links such as "/about" with "https://company.com/about".
# We will use "one shot prompting" in which we provide an example of how it should respond in the prompt.
#
# This is an excellent use case for an LLM, because it requires nuanced understanding. Imagine trying to code this without LLMs by parsing and analyzing the webpage - it would be very hard!
#
# Sidenote: there is a more advanced technique called "Structured Outputs" in which we require the model to respond according to a spec. We cover this technique in Week 8 during our autonomous Agentic AI project.

# %%
link_system_prompt = "You are provided with a list of links found on a webpage. \
You are able to decide which of the links would be most relevant to include in a brochure about the company, \
such as links to an About page, or a Company page, or Careers/Jobs pages.\n"
link_system_prompt += "You should respond in JSON as in this example:"
link_system_prompt += """
{
    "links": [
        {"type": "about page", "url": "https://full.url/goes/here/about"},
        {"type": "careers page": "url": "https://another.full.url/careers"}
    ]
}
"""

# %%
print(link_system_prompt)
# Out:
# You are provided with a list of links found on a webpage. You are able to decide which of the links would be most relevant to include in a brochure about the company, such as links to an About page, or a Company page, or Careers/Jobs pages.
# You should respond in JSON as in this example:
# {
#     "links": [
#         {"type": "about page", "url": "https://full.url/goes/here/about"},
#         {"type": "careers page": "url": "https://another.full.url/careers"}
#     ]
# }

# %%
def get_links_user_prompt(website):
    user_prompt = f"Here is the list of links on the website of {website.url} - "
    user_prompt += "please decide which of these are relevant web links for a brochure about the company, respond with the full https URL in JSON format. \
Do not include Terms of Service, Privacy, email links.\n"
    user_prompt += "Links (some might be relative links):\n"
    user_prompt += "\n".join(website.links)
    return user_prompt

# %%
print(get_links_user_prompt(ed))
# Out:
# Here is the list of links on the website of https://edwarddonner.com - please decide which of these are relevant web links for a brochure about the company, respond with the full https URL in JSON format. Do not include Terms of Service, Privacy, email links.
# Links (some might be relative links):
# https://edwarddonner.com/
# https://edwarddonner.com/connect-four/
# https://edwarddonner.com/outsmart/
# https://edwarddonner.com/about-me-and-about-nebula/
# https://edwarddonner.com/posts/
# https://edwarddonner.com/
# https://news.ycombinator.com
# https://nebula.io/?utm_source=ed&utm_medium=referral
# https://www.prnewswire.com/news-releases/wynden-stark-group-acquires-nyc-venture-backed-tech-startup-untapt-301269512.html
# https://patents.google.com/patent/US20210049536A1/
# https://www.linkedin.com/in/eddonner/
# https://edwarddonner.com/2025/04/21/the-complete-agentic-ai-engineering-course/
# https://edwarddonner.com/2025/04/21/the-complete-agentic-ai-engineering-course/
# https://edwarddonner.com/2025/01/23/llm-workshop-hands-on-with-agents-resources/
# https://edwarddonner.com/2025/01/23/llm-workshop-hands-on-with-agents-resources/
# https://edwarddonner.com/2024/12/21/llm-resources-superdatascience/
# https://edwarddonner.com/2024/12/21/llm-resources-superdatascience/
# https://edwarddonner.com/2024/11/13/llm-engineering-resources/
# https://edwarddonner.com/2024/11/13/llm-engineering-resources/
# https://edwarddonner.com/
# https://edwarddonner.com/connect-four/
# https://edwarddonner.com/outsmart/
# https://edwarddonner.com/about-me-and-about-nebula/
# https://edwarddonner.com/posts/
# mailto:hello@mygroovydomain.com
# https://www.linkedin.com/in/eddonner/
# https://twitter.com/edwarddonner
# https://www.facebook.com/edward.donner.52

# %%
def get_links(url):
    website = Website(url)
    response = openai.chat.completions.create(
        model=MODEL,
        messages=[
            {"role": "system", "content": link_system_prompt},
            {"role": "user", "content": get_links_user_prompt(website)}
      ],
        response_format={"type": "json_object"}
    )
    result = response.choices[0].message.content
    return json.loads(result)

# %%
# Anthropic has made their site harder to scrape, so I'm using HuggingFace..

huggingface = Website("https://huggingface.co")
huggingface.links
# Out:
# ['/',
#  '/models',
#  '/datasets',
#  '/spaces',
#  '/posts',
#  '/docs',
#  '/enterprise',
#  '/pricing',
#  '/login',
#  '/join',
#  '/spaces',
#  '/models',
#  '/deepseek-ai/DeepSeek-Prover-V2-671B',
#  '/nvidia/parakeet-tdt-0.6b-v2',
#  '/nari-labs/Dia-1.6B',
#  '/JetBrains/Mellum-4b-base',
#  '/Qwen/Qwen3-235B-A22B',
#  '/models',
#  '/spaces/enzostvs/deepsite',
#  '/spaces/RiverZ/ICEdit',
#  '/spaces/nari-labs/Dia-1.6B',
#  '/spaces/Qwen/Qwen3-Demo',
#  '/spaces/retwpay/waiNSFWIllustrious_v110',
#  '/spaces',
#  '/datasets/nvidia/Nemotron-CrossThink',
#  '/datasets/rajpurkarlab/ReXGradient-160K',
#  '/datasets/nvidia/OpenMathReasoning',
#  '/datasets/nvidia/OpenCodeReasoning',
#  '/datasets/deepseek-ai/DeepSeek-ProverBench',
#  '/datasets',
#  '/join',
#  '/pricing#endpoints',
#  '/pricing#spaces',
#  '/pricing',
#  '/enterprise',
#  '/enterprise',
#  '/enterprise',
#  '/enterprise',
#  '/enterprise',
#  '/enterprise',
#  '/enterprise',
#  '/allenai',
#  '/facebook',
#  '/amazon',
#  '/google',
#  '/Intel',
#  '/microsoft',
#  '/grammarly',
#  '/Writer',
#  '/docs/transformers',
#  '/docs/diffusers',
#  '/docs/safetensors',
#  '/docs/huggingface_hub',
#  '/docs/tokenizers',
#  '/docs/trl',
#  '/docs/transformers.js',
#  '/docs/smolagents',
#  '/docs/peft',
#  '/docs/datasets',
#  '/docs/text-generation-inference',
#  '/docs/accelerate',
#  '/models',
#  '/datasets',
#  '/spaces',
#  '/tasks',
#  'https://ui.endpoints.huggingface.co',
#  '/chat',
#  '/huggingface',
#  '/brand',
#  '/terms-of-service',
#  '/privacy',
#  'https://apply.workable.com/huggingface/',
#  'mailto:press@huggingface.co',
#  '/learn',
#  '/docs',
#  '/blog',
#  'https://discuss.huggingface.co',
#  'https://status.huggingface.co/',
#  'https://github.com/huggingface',
#  'https://twitter.com/huggingface',
#  'https://www.linkedin.com/company/huggingface/',
#  '/join/discord']

# %%
get_links("https://huggingface.co")
# Out:
# {'links': [{'type': 'about page', 'url': 'https://huggingface.co/huggingface'},
#   {'type': 'careers page', 'url': 'https://apply.workable.com/huggingface/'},
#   {'type': 'website homepage', 'url': 'https://huggingface.co'},
#   {'type': 'blog', 'url': 'https://huggingface.co/blog'},
#   {'type': 'forum', 'url': 'https://discuss.huggingface.co'},
#   {'type': 'GitHub', 'url': 'https://github.com/huggingface'},
#   {'type': 'LinkedIn', 'url': 'https://www.linkedin.com/company/huggingface/'},
#   {'type': 'Twitter', 'url': 'https://twitter.com/huggingface'}]}

# %% [markdown]
# ## Second step: make the brochure!
#
# Assemble all the details into another prompt to GPT4-o

# %%
def get_all_details(url):
    result = "Landing page:\n"
    result += Website(url).get_contents()
    links = get_links(url)
    print("Found links:", links)
    for link in links["links"]:
        result += f"\n\n{link['type']}\n"
        result += Website(link["url"]).get_contents()
    return result

# %%
print(get_all_details("https://huggingface.co"))
# Out:
# Found links: {'links': [{'type': 'about page', 'url': 'https://huggingface.co/huggingface'}, {'type': 'careers page', 'url': 'https://apply.workable.com/huggingface/'}, {'type': 'pricing page', 'url': 'https://huggingface.co/pricing'}, {'type': 'enterprise page', 'url': 'https://huggingface.co/enterprise'}, {'type': 'blog page', 'url': 'https://huggingface.co/blog'}, {'type': 'discussion forum', 'url': 'https://discuss.huggingface.co'}, {'type': 'GitHub page', 'url': 'https://github.com/huggingface'}, {'type': 'Twitter page', 'url': 'https://twitter.com/huggingface'}, {'type': 'LinkedIn page', 'url': 'https://www.linkedin.com/company/huggingface/'}]}
# Landing page:
# Webpage Title:
# Hugging Face – The AI community building the future.
# Webpage Contents:
# Hugging Face
# Models
# Datasets
# Spaces
# Posts
# Docs
# Enterprise
# Pricing
# Log In
# Sign Up
# The AI community building the future.
# The platform where the machine learning community collaborates on models, datasets, and applications.
# Explore AI Apps
# or
# Browse 1M+ models
# Trending on
# this week
# Models
# deepseek-ai/DeepSeek-Prover-V2-671B
# Updated
# 7 days ago
# •
# 3.47k
# •
# 709
# nvidia/parakeet-tdt-0.6b-v2
# Updated
# 6 days ago
# •
# 8.68k
# •
# 406
# nari-labs/Dia-1.6B
# Updated
# 1 day ago
# •
# 128k
# •
# 1.91k
# JetBrains/Mellum-4b-base
# Updated
# 7 days ago
# •
# 1.2k
# •
# 256
# Qwen/Qwen3-235B-A22B
# Updated
# 6 days ago
# •
# 42.8k
# •
# 713
# Browse 1M+ models
# Spaces
# Running
# 6.07k
# 6.07k
# DeepSite
# 🐳
# Generate any application with DeepSeek
# Running
# on
# Zero
# 325
# 325
# ICEdit
# 🖼
# Universal Image Editing is worth a single LoRA
# Running
# on
# Zero
# 1.18k
# 1.18k
# Dia 1.6B
# 👯
# Generate realistic dialogue from a script, using Dia!
# Running
# 440
# 440
# Qwen3 Demo
# 📊
# Generate responses to your messages
# Running
# on
# Zero
# 284
# 284
# WaiNSFWIllustrious V110
# 🖼
# Generate images from textual prompts
# Browse 400k+ applications
# Datasets
# nvidia/Nemotron-CrossThink
# Updated
# 6 days ago
# •
# 2.27k
# •
# 51
# rajpurkarlab/ReXGradient-160K
# Updated
# 1 day ago
# •
# 460
# •
# 39
# nvidia/OpenMathReasoning
# Updated
# 13 days ago
# •
# 27.2k
# •
# 178
# nvidia/OpenCodeReasoning
# Updated
# 2 days ago
# •
# 17.4k
# •
# 353
# deepseek-ai/DeepSeek-ProverBench
# Updated
# 7 days ago
# •
# 1.16k
# •
# 24
# Browse 250k+ datasets
# The Home of Machine Learning
# Create, discover and collaborate on ML better.
# The collaboration platform
# Host and collaborate on unlimited public models, datasets and applications.
# Move faster
# With the HF Open source stack.
# Explore all modalities
# Text, image, video, audio or even 3D.
# Build your portfolio
# Share your work with the world and build your ML profile.
# Sign Up
# Accelerate your ML
# We provide paid Compute and Enterprise solutions.
# Compute
# Deploy on optimized
# Inference Endpoints
# or update your
# Spaces applications
# to a GPU in a few clicks.
# View pricing
# Starting at $0.60/hour for GPU
# Enterprise
# Give your team the most advanced platform to build AI with enterprise-grade security, access controls and
# 			dedicated support.
# Getting started
# Starting at $20/user/month
# Single Sign-On
# Regions
# Priority Support
# Audit Logs
# Resource Groups
# Private Datasets Viewer
# More than 50,000 organizations are using Hugging Face
# Ai2
# Enterprise
# non-profit
# •
# 756 models
# •
# 3.21k followers
# AI at Meta
# Enterprise
# company
# •
# 2.12k models
# •
# 5.81k followers
# Amazon
# company
# •
# 20 models
# •
# 3.13k followers
# Google
# company
# •
# 991 models
# •
# 12.8k followers
# Intel
# company
# •
# 220 models
# •
# 2.51k followers
# Microsoft
# company
# •
# 374 models
# •
# 12.1k followers
# Grammarly
# Enterprise
# company
# •
# 10 models
# •
# 157 followers
# Writer
# Enterprise
# company
# •
# 21 models
# •
# 266 followers
# Our Open Source
# We are building the foundation of ML tooling with the community.
# Transformers
# 143,933
# State-of-the-art ML for PyTorch, TensorFlow, JAX
# Diffusers
# 28,876
# State-of-the-art Diffusion models in PyTorch
# Safetensors
# 3,255
# Safe way to store/distribute neural network weights
# Hub Python Library
# 2,584
# Python client to interact with the Hugging Face Hub
# Tokenizers
# 9,659
# Fast tokenizers optimized for research & production
# TRL
# 13,609
# Train transformers LMs with reinforcement learning
# Transformers.js
# 13,554
# State-of-the-art ML running directly in your browser
# smolagents
# 18,069
# Smol library to build great agents in Python
# PEFT
# 18,312
# Parameter-efficient finetuning for large language models
# Datasets
# 20,074
# Access & share datasets for any ML tasks
# Text Generation Inference
# 10,086
# Serve language models with TGI optimized toolkit
# Accelerate
# 8,684
# Train PyTorch models with multi-GPU, TPU, mixed precision
# System theme
# Website
# Models
# Datasets
# Spaces
# Tasks
# Inference Endpoints
# HuggingChat
# Company
# About
# Brand assets
# Terms of service
# Privacy
# Jobs
# Press
# Resources
# Learn
# Documentation
# Blog
# Forum
# Service Status
# Social
# GitHub
# Twitter
# LinkedIn
# Discord
#
#
#
# about page
# Webpage Title:
# huggingface (Hugging Face)
# Webpage Contents:
# Hugging Face
# Models
# Datasets
# Spaces
# Posts
# Docs
# Enterprise
# Pricing
# Log In
# Sign Up
# Hugging Face
# Enterprise
# company
# Verified
# https://huggingface.co
# huggingface
# huggingface
# Activity Feed
# Follow
# 36,080
# AI & ML interests
# The AI community building the future.
# Recent Activity
# lysandre
# updated
# a dataset
# 1 day ago
# huggingface/transformers-metadata
# Chunte
# new
# activity
# 1 day ago
# huggingface/badges:
# [Added Visualize this dataset]-Update README.md
# Chunte
# new
# activity
# 1 day ago
# huggingface/badges:
# Upload 8 files
# View all activity
# Articles
# Yay! Organizations can now publish blog Articles
# Jan 20
# •
# 42
# Team members
# 215
# +181
# +168
# +147
# +137
# +117
# Organization Card
# Community
# About org cards
# 👋 Hi!
# We are on a mission to democratize
# good
# machine learning, one commit at a time.
# If that sounds like something you should be doing, why don't you
# join us
# !
# For press enquiries, you can
# ✉️ contact our team here
# .
# Collections
# 1
# DistilBERT release
# Original DistilBERT model, checkpoints obtained from using teacher-student learning from the original BERT checkpoints.
# distilbert/distilbert-base-cased
# Fill-Mask
# •
# Updated
# May 6, 2024
# •
# 242k
# •
# 45
# distilbert/distilbert-base-uncased
# Fill-Mask
# •
# Updated
# May 6, 2024
# •
# 12.1M
# •
# •
# 674
# distilbert/distilbert-base-multilingual-cased
# Fill-Mask
# •
# Updated
# May 6, 2024
# •
# 5.98M
# •
# 187
# distilbert/distilbert-base-uncased-finetuned-sst-2-english
# Text Classification
# •
# Updated
# Dec 19, 2023
# •
# 4.35M
# •
# •
# 753
# spaces
# 26
# Sort:
# 		Recently updated
# pinned
# Running
# 85
# Number Tokenization Blog
# 📈
# Explore how tokenization affects arithmetic in LLMs
# huggingface
# Dec 14, 2024
# Running
# 158
# Inference Playground
# 🔋
# Set website theme based on user preference
# huggingface
# 2 days ago
# Running
# 390
# AI Deadlines
# ⚡
# Generate project deadlines
# huggingface
# 8 days ago
# Running
# 3
# Space Build
# 🐨
# Generate static files for spaces
# huggingface
# 19 days ago
# Running
# 90
# InferenceSupport
# 💥
# Discussions about the Inference Providers feature on the Hub
# huggingface
# 21 days ago
# Running
# 537
# Open Source Ai Year In Review 2024
# 😻
# What happened in open-source AI this year, and what’s next?
# huggingface
# Jan 8
# Expand
# 							26
# 								spaces
# models
# 16
# Sort:
# 		Recently updated
# huggingface/timesfm-tourism-monthly
# Updated
# Mar 31
# •
# 253
# •
# 2
# huggingface/CodeBERTa-language-id
# Text Classification
# •
# Updated
# Mar 29, 2024
# •
# 799
# •
# 59
# huggingface/falcon-40b-gptq
# Text Generation
# •
# Updated
# Jun 14, 2023
# •
# 36
# •
# 12
# huggingface/autoformer-tourism-monthly
# Updated
# May 24, 2023
# •
# 28.7k
# •
# 9
# huggingface/distilbert-base-uncased-finetuned-mnli
# Text Classification
# •
# Updated
# Mar 22, 2023
# •
# 191
# •
# 2
# huggingface/informer-tourism-monthly
# Updated
# Feb 24, 2023
# •
# 28k
# •
# 6
# huggingface/time-series-transformer-tourism-monthly
# Updated
# Feb 23, 2023
# •
# 5.13k
# •
# 21
# huggingface/the-no-branch-repo
# Text-to-Image
# •
# Updated
# Feb 10, 2023
# •
# 45
# •
# 5
# huggingface/CodeBERTa-small-v1
# Fill-Mask
# •
# Updated
# Jun 27, 2022
# •
# 85.9k
# •
# 81
# huggingface/test-model-repo
# Updated
# Nov 19, 2021
# •
# 1
# Expand
# 							16
# 								models
# datasets
# 42
# Sort:
# 		Recently updated
# huggingface/transformers-metadata
# Viewer
# •
# Updated
# 1 day ago
# •
# 1.65k
# •
# 1.24k
# •
# 23
# huggingface/documentation-images
# Viewer
# •
# Updated
# 6 days ago
# •
# 52
# •
# 2.91M
# •
# 61
# huggingface/badges
# Viewer
# •
# Updated
# 29 days ago
# •
# 1
# •
# 1.71M
# •
# 43
# huggingface/policy-docs
# Updated
# Mar 20
# •
# 1.17k
# •
# 10
# huggingface/diffusers-metadata
# Viewer
# •
# Updated
# Mar 15
# •
# 69
# •
# 937
# •
# 7
# huggingface/gemini-results-2025-03-03
# Viewer
# •
# Updated
# Mar 4
# •
# 17
# •
# 31
# huggingface/gemini-results-2025-02-28
# Viewer
# •
# Updated
# Mar 1
# •
# 21
# •
# 32
# huggingface/gemini-results-2025-02-27
# Viewer
# •
# Updated
# Feb 28
# •
# 24
# •
# 29
# huggingface/gemini-results-2025-02-25
# Viewer
# •
# Updated
# Feb 26
# •
# 32
# •
# 70
# huggingface/gemini-results-2025-02-24
# Viewer
# •
# Updated
# Feb 25
# •
# 32
# •
# 27
# Expand
# 							42
# 								datasets
# System theme
# Company
# TOS
# Privacy
# About
# Jobs
# Website
# Models
# Datasets
# Spaces
# Pricing
# Docs
#
#
#
# careers page
# Webpage Title:
# Hugging Face - Current Openings
# Webpage Contents:
#
#
#
#
# pricing page
# Webpage Title:
# Hugging Face – Pricing
# Webpage Contents:
# Hugging Face
# Models
# Datasets
# Spaces
# Posts
# Docs
# Enterprise
# Pricing
# Log In
# Sign Up
# Pricing
# Leveling up AI collaboration and compute.
# Users and organizations already use the Hub as a collaboration platform,
# we’re making it easy to seamlessly and scalably launch ML compute directly from the Hub.
# HF Hub
# Collaborate on Machine Learning
# Host unlimited public models, datasets
# Create unlimited orgs with no member limits
# Access the latest ML tools and open source
# Community support
# Forever
# Free
# PRO
# Pro Account
# Unlock advanced HF features
# ZeroGPU and Dev Mode for Spaces
# Free credits across all Inference Providers
# Get early access to upcoming features
# Show your support with a Pro badge
# Subscribe for
# $9
# /month
# Enterprise Hub
# Accelerate your AI roadmap
# SSO and SAML support
# Select data location with Storage Regions
# Precise actions reviews with Audit logs
# Granular access control with Resource groups
# Centralized token control and approval
# Dataset Viewer for private datasets
# Advanced compute options for Spaces
# 5x more ZeroGPU quota for all org members
# Deploy Inference on your own Infra
# Managed billing with yearly commits
# Priority support
# Starting at
# $20
# per user per month
# Spaces Hardware
# Upgrade your Space compute
# Free CPUs
# Build more advanced Spaces
# 7 optimized hardware available
# From CPU to GPU to Accelerators
# Starting at
# $0
# /hour
# Inference Endpoints
# Deploy models on fully managed infrastructure
# Deploy dedicated Endpoints in seconds
# Keep your costs low
# Fully-managed autoscaling
# Enterprise security
# Starting at
# $0.032
# /hour
# Need support to accelerate AI in your organization? View our
# Expert Support
# .
# Hugging Face Hub
# free
# The HF Hub is the central place to explore, experiment, collaborate and build technology with Machine
# 					Learning.
# Join the open source Machine Learning movement!
# →
# Sign Up
# Create with ML
# Packed with ML features, like model eval, dataset viewer and much more.
# Collaborate
# Git based and designed for collaboration at its core.
# Play and learn
# Learn by experimenting and sharing with our awesome community.
# Build your ML portfolio
# Share your work with the world and build your own ML profile.
# Spaces Hardware
# Starting at $0
# Spaces are one of the most popular ways to share ML applications and demos with the world.
# Upgrade your Spaces with our selection of custom on-demand hardware:
# →
# Get started with Spaces
# Name
# CPU
# Memory
# Accelerator
# VRAM
# Hourly price
# CPU Basic
# 2 vCPU
# 16 GB
# -
# -
# FREE
# CPU Upgrade
# 8 vCPU
# 32 GB
# -
# -
# $0.03
# Nvidia T4 - small
# 4 vCPU
# 15 GB
# Nvidia T4
# 16 GB
# $0.40
# Nvidia T4 - medium
# 8 vCPU
# 30 GB
# Nvidia T4
# 16 GB
# $0.60
# 1x Nvidia L4
# 8 vCPU
# 30 GB
# Nvidia L4
# 24 GB
# $0.80
# 4x Nvidia L4
# 48 vCPU
# 186 GB
# Nvidia L4
# 96 GB
# $3.80
# 1x Nvidia L40S
# 8 vCPU
# 62 GB
# Nvidia L4
# 48 GB
# $1.80
# 4x Nvidia L40S
# 48 vCPU
# 382 GB
# Nvidia L4
# 192 GB
# $8.30
# 8x Nvidia L40S
# 192 vCPU
# 1534 GB
# Nvidia L4
# 384 GB
# $23.50
# Nvidia A10G - small
# 4 vCPU
# 15 GB
# Nvidia A10G
# 24 GB
# $1.00
# Nvidia A10G - large
# 12 vCPU
# 46 GB
# Nvidia A10G
# 24 GB
# $1.50
# 2x Nvidia A10G - large
# 24 vCPU
# 92 GB
# Nvidia A10G
# 48 GB
# $3.00
# 4x Nvidia A10G - large
# 48 vCPU
# 184 GB
# Nvidia A10G
# 96 GB
# $5.00
# Nvidia A100 - large
# 12 vCPU
# 142 GB
# Nvidia A100
# 80 GB
# $4.00
# Custom
# on demand
# on demand
# on demand
# on demand
# on demand
# Spaces Persistent Storage
# All Spaces get ephemeral storage for free but you can upgrade and add persistent storage at any time.
# Name
# Storage
# Monthly price
# Small
# 20 GB
# $5
# Medium
# 150 GB
# $25
# Large
# 1 TB
# $100
# Building something cool as a side project? We also offer community GPU grants.
# Inference Endpoints
# Starting at $0.033/hour
# Inference Endpoints (dedicated) offers a secure production solution to easily deploy any ML model on dedicated
# 					and autoscaling infrastructure, right from the HF Hub.
# →
# Learn more
# CPU
# instances
# Provider
# Architecture
# vCPUs
# Memory
# Hourly rate
# aws
# Intel Sapphire Rapids
# 1
# 2GB
# $0.03
# 2
# 4GB
# $0.07
# 4
# 8GB
# $0.13
# 8
# 16GB
# $0.27
# 16
# 32GB
# $0.54
# azure
# Intel Xeon
# 1
# 2GB
# $0.06
# 2
# 4GB
# $0.12
# 4
# 8GB
# $0.24
# 8
# 16GB
# $0.48
# gcp
# Intel Sapphire Rapids
# 1
# 2GB
# $0.05
# 2
# 4GB
# $0.10
# 4
# 8GB
# $0.20
# 8
# 16GB
# $0.40
# Accelerator
# instances
# Provider
# Architecture
# Topology
# Accelerator Memory
# Hourly rate
# aws
# Inf2
# 															Neuron
# x1
# 14.5GB
# $0.75
# x12
# 760GB
# $12.00
# gcp
# TPU
# 															v5e
# 1x1
# 16GB
# $1.20
# 2x2
# 64GB
# $4.75
# 2x4
# 128GB
# $9.50
# GPU
# instances
# Provider
# Architecture
# GPUs
# GPU Memory
# Hourly rate
# aws
# NVIDIA T4
# 1
# 14GB
# $0.50
# 4
# 56GB
# $3.00
# aws
# NVIDIA L4
# 1
# 24GB
# $0.80
# 4
# 96GB
# $3.80
# aws
# NVIDIA L40S
# 1
# 48GB
# $1.80
# 4
# 192GB
# $8.30
# 8
# 384GB
# $23.50
# aws
# NVIDIA A10G
# 1
# 24GB
# $1.00
# 4
# 96GB
# $5.00
# aws
# NVIDIA A100
# 1
# 80GB
# $4.00
# 2
# 160GB
# $8.00
# 4
# 320GB
# $16.00
# 8
# 640GB
# $32.00
# aws
# NVIDIA H200
# 1
# 141GB
# $5.00
# 2
# 282GB
# $10.00
# 4
# 564GB
# $20.00
# 8
# 1128GB
# $40.00
# gcp
# NVIDIA T4
# 1
# 16GB
# $0.50
# gcp
# NVIDIA L4
# 1
# 24GB
# $0.70
# 4
# 96GB
# $3.80
# gcp
# NVIDIA A100
# 1
# 80GB
# $3.60
# 2
# 160GB
# $7.20
# 4
# 320GB
# $14.40
# 8
# 640GB
# $28.80
# gcp
# NVIDIA H100
# 1
# 80GB
# $10.00
# 2
# 160GB
# $20.00
# 4
# 320GB
# $40.00
# 8
# 640GB
# $80.00
# Pro Account
# PRO
# A monthly subscription to access powerful features.
# →
# Get Pro
# ($9/month)
# ZeroGPU
# : Get 5x usage quota and highest GPU queue priority
# Spaces Hosting
# : Create ZeroGPU Spaces with A100 hardware
# Spaces Dev Mode
# : Fast iterations via SSH/VS Code for Spaces
# Inference Providers
# : Get $2 included credits across all Inference Providers
# Dataset Viewer
# : Activate it on private datasets
# Blog Articles
# : Publish articles to the Hugging Face blog
# Social Posts
# : Share short updates with the community
# Features Preview
# : Get early access to upcoming
# 										features
# PRO
# Badge
# :
# 										Show your support on your profile
# System theme
# Website
# Models
# Datasets
# Spaces
# Tasks
# Inference Endpoints
# HuggingChat
# Company
# About
# Brand assets
# Terms of service
# Privacy
# Jobs
# Press
# Resources
# Learn
# Documentation
# Blog
# Forum
# Service Status
# Social
# GitHub
# Twitter
# LinkedIn
# Discord
#
#
#
# enterprise page
# Webpage Title:
# Enterprise Hub - Hugging Face
# Webpage Contents:
# Hugging Face
# Models
# Datasets
# Spaces
# Posts
# Docs
# Enterprise
# Pricing
# Log In
# Sign Up
# Enterprise Hub
# Enterprise-ready version of the world’s leading AI platform
# Subscribe to
# Enterprise Hub
# for $20/user/month with your Hub organization
# Give your organization the most advanced platform to build AI with enterprise-grade security, access controls,
# 			dedicated support and more.
# Single Sign-On
# Connect securely to your identity provider with SSO integration.
# Regions
# Select, manage, and audit the location of your repository data.
# Audit Logs
# Stay in control with comprehensive logs that report on actions taken.
# Resource Groups
# Accurately manage access to repositories with granular access control.
# Token Management
# Centralized token control and custom approval policies for organization access.
# Analytics
# Track and analyze repository usage data in a single dashboard.
# Advanced Compute Options
# Increase scalability and performance with more compute options like ZeroGPU.
# ZeroGPU Quota Boost
# All organization members get 5x more ZeroGPU quota to get the most of Spaces.
# Private Datasets Viewer
# Enable the Dataset Viewer on your private datasets for easier collaboration.
# Advanced security
# Configure organization-wide security policies and default repository visibility.
# Billing
# Control your budget effectively with managed billing and yearly commit options.
# Priority Support
# Maximize your platform usage with priority support from the Hugging Face team.
# Extra Private Storage
# Get an additional 1 TB of private storage for each member of your organization (then $25/month per extra TB).
# Join the most forward-thinking AI organizations
# Everything you already know and love about Hugging Face in Enterprise mode.
# Subscribe to
# Enterprise Hub
# or
# Talk to sales
# NVIDIA
# Enterprise
# company
# •
# 354 models
# •
# 24.7k followers
# Shopify
# Enterprise
# company
# •
# 446 followers
# Snowflake
# Enterprise
# company
# •
# 21 models
# •
# 501 followers
# Together
# Enterprise
# company
# •
# 29 models
# •
# 586 followers
# Qwen
# Enterprise
# company
# •
# 262 models
# •
# 29.6k followers
# Xsolla
# Enterprise
# company
# •
# 134 followers
# Fidelity Investments
# Enterprise
# company
# •
# 140 followers
# Jusbrasil
# Enterprise
# company
# •
# 95 followers
# IBM Granite
# Enterprise
# company
# •
# 117 models
# •
# 1.67k followers
# creditkarma
# Enterprise
# company
# •
# 64 followers
# HyperCLOVA X
# Enterprise
# company
# •
# 3 models
# •
# 267 followers
# Johnson & Johnson
# Enterprise
# company
# •
# 59 followers
# MiniMax
# Enterprise
# company
# •
# 2 models
# •
# 629 followers
# Stability AI
# Enterprise
# company
# •
# 105 models
# •
# 22.5k followers
# Infosys Limited
# Enterprise
# company
# •
# 2 models
# •
# 819 followers
# Nerdy Face
# Enterprise
# company
# •
# 1 model
# •
# 297 followers
# AMD
# Enterprise
# company
# •
# 132 models
# •
# 1.51k followers
# Arm
# Enterprise
# company
# •
# 192 followers
# LiveRAG by AIIR
# Enterprise
# company
# •
# 128 followers
# ServiceNow-AI
# Enterprise
# company
# •
# 3 models
# •
# 232 followers
# Toyota Research Institute
# Enterprise
# company
# •
# 10 models
# •
# 110 followers
# Mercedes-Benz AG
# Enterprise
# company
# •
# 153 followers
# H2O.ai
# Enterprise
# company
# •
# 71 models
# •
# 422 followers
# Technology Innovation Institute
# Enterprise
# company
# •
# 65 models
# •
# 1.32k followers
# HiddenLayer
# Enterprise
# company
# •
# 1 model
# •
# 70 followers
# Novo Nordisk
# Enterprise
# company
# •
# 79 followers
# Liquid AI
# Enterprise
# company
# •
# 133 followers
# Kakao Corp.
# Enterprise
# company
# •
# 3 models
# •
# 130 followers
# Meta Llama
# Enterprise
# company
# •
# 70 models
# •
# 41.9k followers
# AI at Meta
# Enterprise
# company
# •
# 2.12k models
# •
# 5.81k followers
# Orange
# Enterprise
# company
# •
# 7 models
# •
# 221 followers
# ServiceNow
# Enterprise
# company
# •
# 503 followers
# Writer
# Enterprise
# company
# •
# 21 models
# •
# 266 followers
# Deutsche Telekom AG
# Enterprise
# company
# •
# 7 models
# •
# 143 followers
# Nutanix
# Enterprise
# company
# •
# 261 models
# •
# 94 followers
# TNG Technology Consulting GmbH
# Enterprise
# company
# •
# 3 models
# •
# 141 followers
# Aledade Inc
# Enterprise
# company
# •
# 71 followers
# Chegg Inc
# Enterprise
# company
# •
# 85 followers
# Grammarly
# Enterprise
# company
# •
# 10 models
# •
# 157 followers
# Widn AI
# Enterprise
# company
# •
# 48 followers
# BCG X
# Enterprise
# company
# •
# 40 followers
# Twelve Labs
# Enterprise
# company
# •
# 43 followers
# Compliance & Certifications
# GDPR Compliant
# SOC 2 Type 2
# System theme
# Website
# Models
# Datasets
# Spaces
# Tasks
# Inference Endpoints
# HuggingChat
# Company
# About
# Brand assets
# Terms of service
# Privacy
# Jobs
# Press
# Resources
# Learn
# Documentation
# Blog
# Forum
# Service Status
# Social
# GitHub
# Twitter
# LinkedIn
# Discord
#
#
#
# blog page
# Webpage Title:
# Hugging Face – Blog
# Webpage Contents:
# Hugging Face
# Models
# Datasets
# Spaces
# Posts
# Docs
# Enterprise
# Pricing
# Log In
# Sign Up
# Blog, Articles, and discussions
# New Article
# Everything
# community
# guide
# open source collab
# partnerships
# research
# NLP
# Audio
# CV
# RL
# ethics
# Diffusion
# Game Development
# RLHF
# Leaderboard
# Case Studies
# LeRobot
# How to Build an MCP Server with Gradio
# By
# abidlabs
# April 30, 2025
# •
# 80
# Community Articles
# view all
# I trained a Language Model to schedule events with GRPO!
# By
# anakin87
# •
# 8 days ago
# •
# 55
# Introducing HalluMix: A Task-Agnostic, Multi-Domain Benchmark for Detecting Hallucinations in Real-World Scenarios
# By
# quotientai
# and 3 others
# •
# 5 days ago
# •
# 18
# 🦸🏻#14: What Is MCP, and Why Is Everyone – Suddenly!– Talking About It?
# By
# Kseniase
# •
# Mar 17
# •
# 233
# Creating your custom Ghibli Text-to-Image model
# By
# atlasia
# and 3 others
# •
# 6 days ago
# •
# 15
# Uncensor any LLM with abliteration
# By
# mlabonne
# •
# Jun 13, 2024
# •
# 544
# DeepSeek-R1 Dissection: Understanding PPO & GRPO Without Any Prior Reinforcement Learning Knowledge
# By
# NormalUhr
# •
# Feb 7
# •
# 127
# DeepWiki: Best AI Documentation Generator for Any Github Repo
# By
# lynn-mikami
# •
# 9 days ago
# •
# 15
# Introduction to State Space Models (SSM)
# By
# lbourdois
# •
# Jul 19, 2024
# •
# 128
# ColPali: Efficient Document Retrieval with Vision Language Models 👀
# By
# manu
# •
# Jul 5, 2024
# •
# 245
# Mixture of Tunable Experts - Behavior Modification of DeepSeek-R1 at Inference Time
# By
# rbrt
# and 4 others
# •
# Feb 18
# •
# 32
# Building Multimodal RAG Systems: Supercharging Retrieval with MultiModal Embeddings and LLMs
# By
# Omartificial-Intelligence-Space
# •
# 6 days ago
# •
# 6
# Code a simple RAG from scratch
# By
# ngxson
# •
# Oct 29, 2024
# •
# 66
# Bamba-9B-v2 - Fast and powerful!
# By
# ibm-ai-platform
# and 12 others
# •
# 8 days ago
# •
# 26
# A Guide to Running Qwen 3 Locally with Ollama and vLLM
# By
# lynn-mikami
# •
# 8 days ago
# •
# 7
# Navigating the RLHF Landscape: From Policy Gradients to PPO, GAE, and DPO for LLM Alignment
# By
# NormalUhr
# •
# Feb 11
# •
# 27
# What is MoE 2.0? Update Your Knowledge about Mixture-of-experts
# By
# Kseniase
# and 1 other
# •
# 9 days ago
# •
# 6
# Good answers are not necessarily factual answers: an analysis of hallucination in leading LLMs
# By
# davidberenstein1957
# and 1 other
# •
# about 1 hour ago
# •
# 4
# KV Caching Explained: Optimizing Transformer Inference Efficiency
# By
# not-lain
# •
# Jan 30
# •
# 61
# What is test-time compute and how to scale it?
# By
# Kseniase
# and 1 other
# •
# Feb 6
# •
# 82
# OpenManus: The Open Source Alternative to Manus AI
# By
# lynn-mikami
# •
# Mar 30
# •
# 14
# Welcoming Llama Guard 4 on Hugging Face Hub
# By
# merve
# April 29, 2025
# •
# 31
# The 4 Things Qwen-3's Chat Template Teaches Us
# By
# cfahlgren1
# April 30, 2025
# •
# 27
# Tiny Agents: a MCP-powered agent in 50 lines of code
# By
# julien-c
# April 25, 2025
# •
# 218
# Introducing AutoRound: Intel’s Advanced Quantization for LLMs and VLMs
# By
# wenhuach
# April 29, 2025
# •
# 20
# 17 Reasons Why Gradio Isn't Just Another UI Library
# By
# ysharma
# April 16, 2025
# •
# 29
# Cohere on Hugging Face Inference Providers 🔥
# By
# burtenshaw
# April 16, 2025
# •
# 124
# Introducing HELMET
# By
# hyen
# April 16, 2025
# •
# 23
# Hugging Face to sell open-source robots thanks to Pollen Robotics acquisition 🤖
# By
# thomwolf
# April 14, 2025
# •
# 42
# 4M Models Scanned: Protect AI + Hugging Face 6 Months In
# By
# sean-pai
# April 14, 2025
# •
# 28
# Hugging Face and Cloudflare Partner to Make Real-Time Speech and Video Seamless with FastRTC
# By
# freddyaboulton
# April 9, 2025
# •
# 24
# Arabic Leaderboards: Introducing Arabic Instruction Following, Updating AraGen, and More
# By
# alielfilali01
# April 8, 2025
# guest
# •
# 16
# Welcome Llama 4 Maverick & Scout on Hugging Face!
# By
# burtenshaw
# April 5, 2025
# •
# 142
# Journey to 1 Million Gradio Users!
# By
# abidlabs
# April 4, 2025
# •
# 26
# The NLP Course is becoming the LLM Course!
# By
# burtenshaw
# April 3, 2025
# •
# 90
# Previous
# 1
# 2
# 3
# ...
# 41
# Next
# Community Articles
# Sort:
# 		Trending
# I trained a Language Model to schedule events with GRPO!
# By
# anakin87
# •
# 8 days ago
# •
# 55
# Introducing HalluMix: A Task-Agnostic, Multi-Domain Benchmark for Detecting Hallucinations in Real-World Scenarios
# By
# quotientai
# and 3 others
# •
# 5 days ago
# •
# 18
# 🦸🏻#14: What Is MCP, and Why Is Everyone – Suddenly!– Talking About It?
# By
# Kseniase
# •
# Mar 17
# •
# 233
# Creating your custom Ghibli Text-to-Image model
# By
# atlasia
# and 3 others
# •
# 6 days ago
# •
# 15
# Uncensor any LLM with abliteration
# By
# mlabonne
# •
# Jun 13, 2024
# •
# 544
# DeepSeek-R1 Dissection: Understanding PPO & GRPO Without Any Prior Reinforcement Learning Knowledge
# By
# NormalUhr
# •
# Feb 7
# •
# 127
# DeepWiki: Best AI Documentation Generator for Any Github Repo
# By
# lynn-mikami
# •
# 9 days ago
# •
# 15
# Introduction to State Space Models (SSM)
# By
# lbourdois
# •
# Jul 19, 2024
# •
# 128
# ColPali: Efficient Document Retrieval with Vision Language Models 👀
# By
# manu
# •
# Jul 5, 2024
# •
# 245
# Mixture of Tunable Experts - Behavior Modification of DeepSeek-R1 at Inference Time
# By
# rbrt
# and 4 others
# •
# Feb 18
# •
# 32
# Building Multimodal RAG Systems: Supercharging Retrieval with MultiModal Embeddings and LLMs
# By
# Omartificial-Intelligence-Space
# •
# 6 days ago
# •
# 6
# Code a simple RAG from scratch
# By
# ngxson
# •
# Oct 29, 2024
# •
# 66
# Bamba-9B-v2 - Fast and powerful!
# By
# ibm-ai-platform
# and 12 others
# •
# 8 days ago
# •
# 26
# A Guide to Running Qwen 3 Locally with Ollama and vLLM
# By
# lynn-mikami
# •
# 8 days ago
# •
# 7
# Navigating the RLHF Landscape: From Policy Gradients to PPO, GAE, and DPO for LLM Alignment
# By
# NormalUhr
# •
# Feb 11
# •
# 27
# What is MoE 2.0? Update Your Knowledge about Mixture-of-experts
# By
# Kseniase
# and 1 other
# •
# 9 days ago
# •
# 6
# Good answers are not necessarily factual answers: an analysis of hallucination in leading LLMs
# By
# davidberenstein1957
# and 1 other
# •
# about 1 hour ago
# •
# 4
# KV Caching Explained: Optimizing Transformer Inference Efficiency
# By
# not-lain
# •
# Jan 30
# •
# 61
# What is test-time compute and how to scale it?
# By
# Kseniase
# and 1 other
# •
# Feb 6
# •
# 82
# OpenManus: The Open Source Alternative to Manus AI
# By
# lynn-mikami
# •
# Mar 30
# •
# 14
# View all
# System theme
# Company
# TOS
# Privacy
# About
# Jobs
# Website
# Models
# Datasets
# Spaces
# Pricing
# Docs
#
#
#
# discussion forum
# Webpage Title:
# Hugging Face Forums - Hugging Face Community Discussion
# Webpage Contents:
# Hugging Face Forums
# Topic
# Replies
# Views
# Activity
# How to resume training from a checkpoint using huggingface trainer
# 🤗Transformers
# 2
# 9
# May 7, 2025
# Persistent DNS Resolution Errors
# Spaces
# 6
# 21
# May 7, 2025
# But is there even a single model working here?!
# Models
# 1
# 40
# May 6, 2025
# Runtime error at Photomaker V2
# Beginners
# 1
# 10
# May 6, 2025
# Dummy_agent_library.ipynb not working for me
# Course
# 3
# 21
# May 7, 2025
# Holy Tariffs - Is there a USA source for LeRobot servo motors?
# Beginners
# 0
# 7
# May 7, 2025
# Inference API stopped working
# Inference Endpoints on the Hub
# 40
# 1265
# May 7, 2025
# AutoTokenizer.from_pretrained() suddenly raises an error
# 🤗Transformers
# 2
# 15
# May 7, 2025
# Docker Space Build Fails: "Build Queued" then "exit code 1" with no detailed logs
# Beginners
# 1
# 7
# May 7, 2025
# API inference key not working
# Beginners
# 1
# 21
# May 6, 2025
# https://api-inference.huggingface.co/models/sentence-transformers/paraphrase-MiniLM-L6-v2
# Beginners
# 6
# 54
# May 6, 2025
# 404 downloading models
# Models
# 3
# 19
# May 7, 2025
# Extraction of tabular data from a PDF
# Beginners
# 0
# 8
# May 6, 2025
# Not clear about how to run the agent locally
# Beginners
# 1
# 10
# May 6, 2025
# Load a COCO format database from disk for DETR
# 🤗Datasets
# 1
# 7
# May 7, 2025
# Unable to run CodeAgent withlocal trasformers
# Beginners
# 3
# 28
# May 6, 2025
# How to edit website after huggingface has built it
# Beginners
# 0
# 7
# May 6, 2025
# Unable to access model with Inference Client
# Beginners
# 2
# 38
# May 6, 2025
# Can I get clarification on what exactly transformers does vs what the model does?
# Models
# 3
# 40
# May 6, 2025
# TrainingArgument does not work on colab
# Beginners
# 20
# 12095
# May 7, 2025
# Prepare dataset from YOLO format to COCO for DETR
# 🤗Transformers
# 4
# 4957
# May 6, 2025
# Price model to avoid limits
# Beginners
# 2
# 23
# May 5, 2025
# Progress not saved in AI Agents course
# Course
# 1
# 13
# May 6, 2025
# Inference API budget, billing limit
# Site Feedback
# 16
# 3078
# May 6, 2025
# I fine-tuned the llama language model, but how should I adjust the prompt?
# Beginners
# 2
# 18
# May 5, 2025
# How do you track Hugging Face Inference API costs alongside other AI services?
# Show and Tell
# 0
# 9
# May 6, 2025
# Error in HF Space Docker
# Beginners
# 15
# 378
# April 22, 2025
# How many files and how many pages
# Beginners
# 5
# 20
# May 5, 2025
# Related to Claude Model
# Models
# 1
# 8
# May 5, 2025
# Big text dataset loading for training
# 🤗Datasets
# 1
# 13
# May 5, 2025
# next page →
# Home
# Categories
# Guidelines
# Terms of Service
# Privacy Policy
# Powered by
# Discourse
# , best viewed with JavaScript enabled
#
#
#
# GitHub page
# Webpage Title:
# Hugging Face · GitHub
# Webpage Contents:
# Skip to content
# Navigation Menu
# Toggle navigation
# Sign in
# huggingface
# Product
# GitHub Copilot
# Write better code with AI
# GitHub Advanced Security
# Find and fix vulnerabilities
# Actions
# Automate any workflow
# Codespaces
# Instant dev environments
# Issues
# Plan and track work
# Code Review
# Manage code changes
# Discussions
# Collaborate outside of code
# Code Search
# Find more, search less
# Explore
# Why GitHub
# All features
# Documentation
# GitHub Skills
# Blog
# Solutions
# By company size
# Enterprises
# Small and medium teams
# Startups
# Nonprofits
# By use case
# DevSecOps
# DevOps
# CI/CD
# View all use cases
# By industry
# Healthcare
# Financial services
# Manufacturing
# Government
# View all industries
# View all solutions
# Resources
# Topics
# AI
# DevOps
# Security
# Software Development
# View all
# Explore
# Learning Pathways
# Events & Webinars
# Ebooks & Whitepapers
# Customer Stories
# Partners
# Executive Insights
# Open Source
# GitHub Sponsors
# Fund open source developers
# The ReadME Project
# GitHub community articles
# Repositories
# Topics
# Trending
# Collections
# Enterprise
# Enterprise platform
# AI-powered developer platform
# Available add-ons
# GitHub Advanced Security
# Enterprise-grade security features
# Copilot for business
# Enterprise-grade AI features
# Premium Support
# Enterprise-grade 24/7 support
# Pricing
# Search or jump to...
# Search code, repositories, users, issues, pull requests...
# Search
# Clear
# Search syntax tips
# Provide feedback
# We read every piece of feedback, and take your input very seriously.
# Include my email address so I can be contacted
# Cancel
# Submit feedback
# Saved searches
# Use saved searches to filter your results more quickly
# Cancel
# Create saved search
# Sign in
# Sign up
# Reseting focus
# You signed in with another tab or window.
# Reload
# to refresh your session.
# You signed out in another tab or window.
# Reload
# to refresh your session.
# You switched accounts on another tab or window.
# Reload
# to refresh your session.
# Dismiss alert
# Hugging Face
# The AI community building the future.
# Verified
# We've verified that the organization
# huggingface
# controls the domain:
# huggingface.co
# Learn more about verified organizations
# 48.5k
# followers
# NYC + Paris
# https://huggingface.co/
# X
# @huggingface
# Overview
# Repositories
# Projects
# Packages
# People
# Sponsoring
# 0
# More
# Overview
# Repositories
# Projects
# Packages
# People
# Sponsoring
# Pinned
# Loading
# transformers
# transformers
# Public
# 🤗 Transformers: State-of-the-art Machine Learning for Pytorch, TensorFlow, and JAX.
# Python
# 144k
# 28.9k
# diffusers
# diffusers
# Public
# 🤗 Diffusers: State-of-the-art diffusion models for image, video, and audio generation in PyTorch and FLAX.
# Python
# 28.9k
# 5.9k
# datasets
# datasets
# Public
# 🤗 The largest hub of ready-to-use datasets for ML models with fast, easy-to-use and efficient data manipulation tools
# Python
# 20.1k
# 2.8k
# peft
# peft
# Public
# 🤗 PEFT: State-of-the-art Parameter-Efficient Fine-Tuning.
# Python
# 18.3k
# 1.9k
# accelerate
# accelerate
# Public
# 🚀 A simple way to launch, train, and use PyTorch models on almost any device and distributed configuration, automatic mixed precision (including fp8), and easy-to-configure FSDP and DeepSpeed support
# Python
# 8.7k
# 1.1k
# optimum
# optimum
# Public
# 🚀 Accelerate inference and training of 🤗 Transformers, Diffusers, TIMM and Sentence Transformers with easy to use hardware optimization tools
# Python
# 2.9k
# 532
# Repositories
# Loading
# Type
# Select type
# Forks
# Archived
# Mirrors
# Templates
# Language
# Select language
# All
# C
# C#
# C++
# Cuda
# Dockerfile
# Go
# Handlebars
# HTML
# Java
# JavaScript
# Jupyter Notebook
# Kotlin
# Lua
# MDX
# Mustache
# Nix
# Python
# Rust
# Shell
# Smarty
# Svelte
# Swift
# TypeScript
# Sort
# Select order
# Last updated
# Name
# Stars
# Showing 10 of 308 repositories
# huggingface.js
# Public
# Utilities to use the Hugging Face Hub API
# huggingface/huggingface.js’s past year of commit activity
# TypeScript
# 1,659
# MIT
# 372
# 106
# (5 issues need help)
# 58
# Updated
# May 7, 2025
# hub-docs
# Public
# Docs of the Hugging Face Hub
# huggingface/hub-docs’s past year of commit activity
# Handlebars
# 387
# Apache-2.0
# 303
# 107
# 26
# Updated
# May 7, 2025
# diffusers
# Public
# 🤗 Diffusers: State-of-the-art diffusion models for image, video, and audio generation in PyTorch and FLAX.
# huggingface/diffusers’s past year of commit activity
# Python
# 28,876
# Apache-2.0
# 5,932
# 498
# (11 issues need help)
# 187
# Updated
# May 7, 2025
# lerobot
# Public
# 🤗 LeRobot: Making AI for Robotics more accessible with end-to-end learning
# huggingface/lerobot’s past year of commit activity
# Python
# 13,271
# Apache-2.0
# 1,528
# 188
# 141
# Updated
# May 7, 2025
# open-r1
# Public
# Fully open reproduction of DeepSeek-R1
# huggingface/open-r1’s past year of commit activity
# Python
# 24,308
# Apache-2.0
# 2,231
# 257
# 37
# Updated
# May 7, 2025
# transformers
# Public
# 🤗 Transformers: State-of-the-art Machine Learning for Pytorch, TensorFlow, and JAX.
# huggingface/transformers’s past year of commit activity
# Python
# 143,937
# Apache-2.0
# 28,859
# 1,049
# (2 issues need help)
# 735
# Updated
# May 7, 2025
# optimum-intel
# Public
# 🤗 Optimum Intel: Accelerate inference with Intel optimization tools
# huggingface/optimum-intel’s past year of commit activity
# Jupyter Notebook
# 461
# Apache-2.0
# 130
# 28
# 17
# Updated
# May 7, 2025
# controlnet_aux
# Public
# huggingface/controlnet_aux’s past year of commit activity
# Python
# 442
# Apache-2.0
# 95
# 41
# 9
# Updated
# May 7, 2025
# xet-core
# Public
# xet client tech, used in huggingface_hub
# huggingface/xet-core’s past year of commit activity
# Rust
# 92
# Apache-2.0
# 11
# 4
# 14
# Updated
# May 7, 2025
# trl
# Public
# Train transformer language models with reinforcement learning.
# huggingface/trl’s past year of commit activity
# Python
# 13,610
# Apache-2.0
# 1,866
# 380
# 67
# Updated
# May 7, 2025
# View all repositories
# People
# View all
# Top languages
# Python
# Jupyter Notebook
# Rust
# TypeScript
# JavaScript
# Most used topics
# pytorch
# machine-learning
# nlp
# transformers
# deep-learning
# Footer
# © 2025 GitHub, Inc.
# Footer navigation
# Terms
# Privacy
# Security
# Status
# Docs
# Contact
# Manage cookies
# Do not share my personal information
# You can’t perform that action at this time.
#
#
#
# Twitter page
# Webpage Title:
# No title found
# Webpage Contents:
# JavaScript is not available.
# We’ve detected that JavaScript is disabled in this browser. Please enable JavaScript or switch to a supported browser to continue using x.com. You can see a list of supported browsers in our Help Center.
# Help Center
# Terms of Service
# Privacy Policy
# Cookie Policy
# Imprint
# Ads info
# © 2025 X Corp.
# Something went wrong, but don’t fret — let’s give it another shot.
# Try again
# Some privacy related extensions may cause issues on x.com. Please disable them and try again.
#
#
#
# LinkedIn page
# Webpage Title:
# Hugging Face | LinkedIn
# Webpage Contents:
# Skip to main content
# LinkedIn
# Articles
# People
# Learning
# Jobs
# Games
# Get the app
# Join now
# Sign in
# Hugging Face
# Software Development
# The AI community building the future.
# See jobs
# Follow
# View all 532 employees
# Report this company
# About us
# The AI community building the future.
# Website
# https://huggingface.co
# External link for Hugging Face
# Industry
# Software Development
# Company size
# 51-200 employees
# Type
# Privately Held
# Founded
# 2016
# Specialties
# machine learning, natural language processing, and deep learning
# Products
# Hugging Face
# Hugging Face
# Natural Language Processing (NLP) Software
# We’re on a journey to solve and democratize artificial intelligence through natural language.
# Locations
# Primary
# Get directions
# Paris, FR
# Get directions
# Employees at Hugging Face
# Ludovic Huraux
# Rajat Arya
# Tech Lead & Software Engineer @ HF | prev: co-founder XetHub, Apple, Turi, AWS, Microsoft
# Jeff Boudier
# Product + Growth at Hugging Face
# Terrence Rohan
# Seed Investor
# See all employees
# Updates
# Hugging Face
# reposted this
# Merve Noyan
# open-sourceress at 🤗 | Google Developer Expert in Machine Learning, MSc Candidate in Data Science
# 17h
# Report this post
# A ton of impactful models and datasets in open AI past week, let's summarize the best 🤩 Link to the collection of them in comments 💬
#
# 💬
# Qwen
# made it rain! They released Qwen3: new dense and MoE models ranging from 0.6B to 235B 🤯 as well as Qwen2.5-Omni, any-to-any model in 3B and 7B!
# >
# Microsoft AI
# released Phi4 reasoning models (that also come in mini and plus sizes)
# >
# NVIDIA
# released new CoT reasoning datasets
# 🖼️ >
# ByteDance
# released UI-TARS-1.5, native multimodal UI parsing agentic model
# > Meta released EdgeTAM, an on-device object tracking model (SAM2 variant)
# 🗣️
# NVIDIA
# released parakeet-tdt-0.6b-v2, a smol 600M automatic speech recognition model
# > Nari released Dia, a 1.6B text-to-speech model
# > Moonshot AI released Kimi Audio, a new audio understanding, generation, conversation model
# 👩🏻💻
# JetBrains
# released Melium models in base and SFT for coding
# > Tesslate released UIGEN-T2-7B, a new text-to-frontend-code model 🤩
# 79
# 3 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Aymeric Roucher
# Leading agents @ Hugging Face 🤗 | Polytechnique - Cambridge
# 17h
# Edited
# Report this post
# 𝗟𝗮𝘂𝗻𝗰𝗵𝗶𝗻𝗴 𝗖𝗼𝗺𝗽𝘂𝘁𝗲𝗿 𝗨𝘀𝗲 𝗶𝗻 𝘀𝗺𝗼𝗹𝗮𝗴𝗲𝗻𝘁𝘀! 🥳
#
# As vision models become more capable, they become able to power complex agentic workflows. Especially Qwen-VL models, that support built-in grounding, i.e. ability to locate any element in an image by its coordinates, thus to click any item on a screenshot.
#
# ➡️ So we worked with
# Thomas Wolf
# ,
# Leandro von Werra
# and
# Miquel Àngel Farré
# to build Computer Use in smolagents. 🚀
#
# Our Computer Use agent works wonders! I asked it how long the soldiers from Alexander had walked from their departure in Macedonia, all the way to India, when they decided they were too tired to continue. It turns out, they had walked quite a bit!
#
# Try the demo here 👉
# https://lnkd.in/eccpVyuD
# …more
# 443
# 29 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Luis Wiedmann
# Research @ Hugging Face | Student @ l’X & TUM
# 18h
# Report this post
# We've just open-sourced nanoVLM, a pure PyTorch library for training Vision-Language Models (VLMs) from scratch — in just 750 lines of code! 🚀
#
# With just 6 hours of training on a single NVIDIA H100 GPU, nanoVLM-222M achieves a 35.3% score on MMStar, matching SmolVLM-256M performance — but using 100x fewer GPU hours. 👀
#
# You can even comfortably train nanoVLM in a free Google Colab notebook! 🤯
#
# nanoVLM, inspired by Andrej Karpathy's nanoGPT, is designed to be simple, readable, and easily modifiable. The whole model is implemented in ~750 lines of code, and the training in ~200 lines of code.
#
# It consists of a:
# 🧠 SigLiP-ViT vision encoder
# 🗣️ LLaMA-style language decoder
# 🔁 Modality projection layer to connect vision and text
#
# We'd love to see what you build with nanoVLM — share your creations with us! Links in the comments!
# 1,491
# 30 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Ben Burtenshaw
# Machine Learning Advocacy @ 🤗 Hugging Face
# 18h
# Edited
# Report this post
# The
# Hugging Face
# LLM course has new videos! 📽️ Join the course and check them out!
#
# 🔗
# https://lnkd.in/epgEBujr
# These videos use our new video generation setup for education content. Stay tuned to hear more.
# …more
# 150
# 2 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Sayak Paul
# ML @ Hugging Face 🤗
# 1d
# Report this post
# We are shipping a new utility in 🤗 Accelerate that lets you save memory.
#
# The idea is that we keep the params in lower-precision & upcast them only when needed in a forward pass.
#
# Simply attach a hook and voila!
#
# Performance loss depends on the model being used. At least for diffusion models, we see none to very minimal differences. On "google/siglip-so400m-patch14-384", I obtained pretty massive improvements on memory consumption.
#
# This, of course, prioritizes memory optimization over latency reduction.
#
# 📄 Docs:
# https://lnkd.in/g6twrfBz
# 👨💻 PR:
# https://lnkd.in/ghubdVTT
# 166
# 15 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Sayak Paul
# ML @ Hugging Face 🤗
# 1w
# Report this post
# Excited to release ReflectionFlow -- a framework that enables text-to-image diffusion models to refine their own output through reflection
#
# We release GenRef-1M, a large-scale dataset consisting of (good_img, bad_img, reflection) triplets. Through extensive experiments, we show that ReflectionFlow acts as a reliable test-time scaling framework, providing multiple degrees of freedom.
#
# To obtain an image generation model with self-reflection capabilities, we had to first obtain  a suitable dataset. This is where the GenRef-1M dataset comes in.
#
# We developed a scalable and fully automated pipeline to do so. Incorporating diverse data sources helped us cover a wide range of tasks with varying amounts of complexity.
#
# To generate the reflections in GenRef-1M, we fine-tuned Qwen2.5-VL-7B on the samples generated by closed-source APIs, and we open-source that dataset too.
#
# We fine-tuned Flux.1-Dev on the GenRef dataset using the OminiControl framework. To use ReflectionFlow during inference, we study its behaviour with the other two popular axes of test-time scaling (TTS):
#
# (1) noise-level (better noises)
# (2) prompt-level (better prompts)
#
# When added on top of traditional noise-level and prompt-level scaling, ReflectionFlow shows significant improvements on GenEval.
#
# Check all details and the release artifacts here:
# https://lnkd.in/esQPt5Yx
# Work done with Le Zhuo, Liangbing Zhao, yours truly, Yue Liao, Renrui Zhang, Yi Xin, Peng Gao,
# Mohamed (Mo) Elhoseiny
# , and
# Hongsheng Li
# .
# 280
# 16 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Merve Noyan
# open-sourceress at 🤗 | Google Developer Expert in Machine Learning, MSc Candidate in Data Science
# 1d
# Report this post
# A real-time object detector much faster and accurate than YOLO with Apache 2.0 license just landed to
# Hugging Face
# transformers 🔥
#
# D-FINE is the sota real-time object detector that runs on T4 (free Colab) 🤩
# Keep reading  for the paper explainer, find links to notebooks & demo in comments 💬
# Regular object detectors attempt to predict bounding boxes in (x, y, w, h) pixel perfect coordinates, which is very rigid and hard to solve 🥲☹️
#
# D-FINE formulates object detection as a distribution for bounding box coordinates, refines them iteratively, and it's more accurate 🤩
# Another core idea behind this model is Global Optimal Localization Self-Distillation ⤵️
# this model uses final layer's distribution output (sort of like a teacher) to distill to earlier layers to make early layers more performant.
# …more
# 1,187
# 42 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Pavel Iakubovskii
# MLE @ Hugging Face 🤗 | Kaggle Competitions Master | Creator of segmentation_models.pytorch
# 1d
# Report this post
# 🔥 Real-Time Object Detection just got a HUGE upgrade on 🤗 Transformers! Meet D-Fine! 🔥
#
# The D-Fine model family has been merged into the
# Hugging Face
# Transformers library, bringing state-of-the-art real-time object detection capabilities. A massive thank you to
# Vladislav Bronzov
# for contributing this powerful model!  🙌
#
# Why is D-Fine a game-changer?
# 🚀 SOTA Performance: the best real-time object detection model, balancing speed and accuracy exceptionally well.
# 🌎 Truly Open: comes with a permissive Apache 2.0 license, making it perfect for both research and commercial applications.
# ⚙️ Flexible Sizes: available in 5 sizes (nano, small, medium, large, and xlarge) to fit various latency constraints.
# 🧠 Various Pretraining: comes with checkpoints trained on COCO, the large-scale Objects365 dataset, and Objects365 -> fine-tuned on COCO for robust performance.
#
# 🔍 Explore Now:
#  - Demo Space with Image and Video support:
# https://lnkd.in/dbzZc_WB
# - Model Checkpoints:
# https://lnkd.in/dR7BNBFF
# 💻 Quickstart with these notebooks:
#  - Inference:
# https://lnkd.in/d3HfXGUQ
# - Fine-tuning on a custom dataset:
# https://lnkd.in/dje4V8DG
# #MachineLearning
# #ComputerVision
# #ObjectDetection
# #HuggingFace
# #Transformers
# #DFine
# …more
# 920
# 27 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Ben Burtenshaw
# Machine Learning Advocacy @ 🤗 Hugging Face
# 1d
# Report this post
# Evaluating LLMs with judges is becoming common, but it can often depend heavily on the judges prompt. It makes sense to optimize and squeeze everything you can out of that prompt based on evidence.
#
# - This paper proposes a strategy for automated quality evaluation prompts by inverting responses.
# - Human evaluation is considered the gold standard, but it can be inconsistent and biased.
# - LLMs as judges evaluators offer scalability, but their performance is highly dependent on prompt design – even small tweaks can cause big differences.
# - the authors introduce a novel inversion learning method. Instead of relying on hand-crafted prompts, their system automatically learns to generate effective, model-specific evaluation prompts.
#
# Their approach produced consistent evaluations across a range of tasks, with just a single sample.
# 212
# 11 Comments
# Like
# Comment
# Share
# Hugging Face
# 950,173 followers
# 1d
# Report this post
# Tiny Agents 💟
# Julien Chaumond
# CTO at Hugging Face
# 2d
# Thanks to the community, you can now run Tiny Agents (powered by
# Hugging Face
# mcp-client in
# huggingface.js
# ) fully local 💟
#
# If you have Qwen3 14B running locally (in LM Studio for instance) – or any other tool-compatible model! – just run this:
#
# ```
# ENDPOINT_URL=http://localhost:1234/v1 \
# npx @huggingface/mcp-client
# ```
#
# Fully local AI is a game-changer 🔥
# 236
# 6 Comments
# Like
# Comment
# Share
# Join now to see what you are missing
# Find people you know at Hugging Face
# Browse recommended jobs for you
# View all updates, news, and articles
# Join now
# Similar pages
# Anthropic
# Research Services
# Perplexity
# Software Development
# San Francisco, California
# Mistral AI
# Technology, Information and Internet
# Paris, France
# OpenAI
# Research Services
# San Francisco, CA
# LangChain
# Technology, Information and Internet
# Generative AI
# Technology, Information and Internet
# DeepLearning.AI
# Software Development
# Palo Alto, California
# Google DeepMind
# Research Services
# London, London
# Cohere
# Software Development
# Toronto, Ontario
# LlamaIndex
# Technology, Information and Internet
# San Francisco, California
# Show more similar pages
# Show fewer similar pages
# Browse jobs
# Engineer jobs
# 555,845 open jobs
# Machine Learning Engineer jobs
# 148,937 open jobs
# Scientist jobs
# 48,969 open jobs
# Software Engineer jobs
# 300,699 open jobs
# Analyst jobs
# 694,057 open jobs
# Intern jobs
# 71,196 open jobs
# Developer jobs
# 258,935 open jobs
# Manager jobs
# 1,880,925 open jobs
# Product Manager jobs
# 199,941 open jobs
# Director jobs
# 1,220,357 open jobs
# Python Developer jobs
# 46,642 open jobs
# Data Scientist jobs
# 264,158 open jobs
# Data Analyst jobs
# 329,009 open jobs
# Senior Software Engineer jobs
# 78,145 open jobs
# Project Manager jobs
# 253,048 open jobs
# Researcher jobs
# 195,654 open jobs
# Associate jobs
# 1,091,945 open jobs
# Data Engineer jobs
# 192,126 open jobs
# Vice President jobs
# 235,270 open jobs
# Specialist jobs
# 768,666 open jobs
# Show more jobs like this
# Show fewer jobs like this
# Funding
# Hugging Face
# 8 total rounds
# Last Round
# Series unknown
# Sep 1, 2024
# External Crunchbase Link for last round of funding
# See more info on
# crunchbase
# More searches
# More searches
# Engineer jobs
# Scientist jobs
# Machine Learning Engineer jobs
# Software Engineer jobs
# Intern jobs
# Developer jobs
# Analyst jobs
# Manager jobs
# Senior Software Engineer jobs
# Data Scientist jobs
# Researcher jobs
# Product Manager jobs
# Director jobs
# Associate jobs
# Intelligence Specialist jobs
# Data Analyst jobs
# Data Science Specialist jobs
# Python Developer jobs
# Quantitative Analyst jobs
# Project Manager jobs
# Account Executive jobs
# Specialist jobs
# Data Engineer jobs
# Designer jobs
# Quantitative Researcher jobs
# Consultant jobs
# Solutions Architect jobs
# Vice President jobs
# User Experience Designer jobs
# Head jobs
# Full Stack Engineer jobs
# Engineering Manager jobs
# Software Engineer Intern jobs
# Junior Software Engineer jobs
# Software Intern jobs
# Product Designer jobs
# Solutions Engineer jobs
# Staff Software Engineer jobs
# Program Manager jobs
# Senior Scientist jobs
# Writer jobs
# Research Intern jobs
# Senior Product Manager jobs
# Summer Intern jobs
# Account Manager jobs
# Recruiter jobs
# Lead jobs
# Research Engineer jobs
# Computer Science Intern jobs
# Platform Engineer jobs
# Junior Developer jobs
# Android Developer jobs
# User Experience Researcher jobs
# Java Software Engineer jobs
# Site Reliability Engineer jobs
# Graduate jobs
# Software Engineering Manager jobs
# Representative jobs
# Business Development Specialist jobs
# Computer Engineer jobs
# LinkedIn
# © 2025
# About
# Accessibility
# User Agreement
# Privacy Policy
# Cookie Policy
# Copyright Policy
# Brand Policy
# Guest Controls
# Community Guidelines
# العربية (Arabic)
# বাংলা (Bangla)
# Čeština (Czech)
# Dansk (Danish)
# Deutsch (German)
# Ελληνικά (Greek)
# English (English)
# Español (Spanish)
# فارسی (Persian)
# Suomi (Finnish)
# Français (French)
# हिंदी (Hindi)
# Magyar (Hungarian)
# Bahasa Indonesia (Indonesian)
# Italiano (Italian)
# עברית (Hebrew)
# 日本語 (Japanese)
# 한국어 (Korean)
# मराठी (Marathi)
# Bahasa Malaysia (Malay)
# Nederlands (Dutch)
# Norsk (Norwegian)
# ਪੰਜਾਬੀ (Punjabi)
# Polski (Polish)
# Português (Portuguese)
# Română (Romanian)
# Русский (Russian)
# Svenska (Swedish)
# తెలుగు (Telugu)
# ภาษาไทย (Thai)
# Tagalog (Tagalog)
# Türkçe (Turkish)
# Українська (Ukrainian)
# Tiếng Việt (Vietnamese)
# 简体中文 (Chinese (Simplified))
# 正體中文 (Chinese (Traditional))
# Language
# Agree & Join LinkedIn
# By clicking Continue to join or sign in, you agree to LinkedIn’s
# User Agreement
# ,
# Privacy Policy
# , and
# Cookie Policy
# .
# Sign in to see who you already know at Hugging Face
# Sign in
# Welcome back
# Email or phone
# Password
# Show
# Forgot password?
# Sign in
# or
# By clicking Continue to join or sign in, you agree to LinkedIn’s
# User Agreement
# ,
# Privacy Policy
# , and
# Cookie Policy
# .
# New to LinkedIn?
# Join now
# or
# New to LinkedIn?
# Join now
# By clicking Continue to join or sign in, you agree to LinkedIn’s
# User Agreement
# ,
# Privacy Policy
# , and
# Cookie Policy
# .
# LinkedIn
# LinkedIn is better on the app
# Don’t have the app? Get it in the Microsoft Store.
# Open the app

# %%
system_prompt = "You are an assistant that analyzes the contents of several relevant pages from a company website \
and creates a short brochure about the company for prospective customers, investors and recruits. Respond in markdown.\
Include details of company culture, customers and careers/jobs if you have the information."

# Or uncomment the lines below for a more humorous brochure - this demonstrates how easy it is to incorporate 'tone':

# system_prompt = "You are an assistant that analyzes the contents of several relevant pages from a company website \
# and creates a short humorous, entertaining, jokey brochure about the company for prospective customers, investors and recruits. Respond in markdown.\
# Include details of company culture, customers and careers/jobs if you have the information."

# %%
def get_brochure_user_prompt(company_name, url):
    user_prompt = f"You are looking at a company called: {company_name}\n"
    user_prompt += f"Here are the contents of its landing page and other relevant pages; use this information to build a short brochure of the company in markdown.\n"
    user_prompt += get_all_details(url)
    user_prompt = user_prompt[:5_000] # Truncate if more than 5,000 characters
    return user_prompt

# %%
get_brochure_user_prompt("HuggingFace", "https://huggingface.co")
# Out:
# Found links: {'links': [{'type': 'about page', 'url': 'https://huggingface.co/about'}, {'type': 'careers page', 'url': 'https://apply.workable.com/huggingface/'}, {'type': 'company page', 'url': 'https://huggingface.co/enterprise'}, {'type': 'blog page', 'url': 'https://huggingface.co/blog'}, {'type': 'community page', 'url': 'https://discuss.huggingface.co'}, {'type': 'LinkedIn page', 'url': 'https://www.linkedin.com/company/huggingface/'}, {'type': 'Twitter page', 'url': 'https://twitter.com/huggingface'}]}
# "You are looking at a company called: HuggingFace\nHere are the contents of its landing page and other relevant pages; use this information to build a short brochure of the company in markdown.\nLanding page:\nWebpage Title:\nHugging Face – The AI community building the future.\nWebpage Contents:\nHugging Face\nModels\nDatasets\nSpaces\nPosts\nDocs\nEnterprise\nPricing\nLog In\nSign Up\nThe AI community building the future.\nThe platform where the machine learning community collaborates on models, datasets, and applications.\nExplore AI Apps\nor\nBrowse 1M+ models\nTrending on\nthis week\nModels\ndeepseek-ai/DeepSeek-Prover-V2-671B\nUpdated\n7 days ago\n•\n3.47k\n•\n709\nnvidia/parakeet-tdt-0.6b-v2\nUpdated\n6 days ago\n•\n8.68k\n•\n406\nnari-labs/Dia-1.6B\nUpdated\n1 day ago\n•\n128k\n•\n1.91k\nJetBrains/Mellum-4b-base\nUpdated\n7 days ago\n•\n1.2k\n•\n256\nQwen/Qwen3-235B-A22B\nUpdated\n6 days ago\n•\n42.8k\n•\n713\nBrowse 1M+ models\nSpaces\nRunning\n6.07k\n6.07k\nDeepSite\n🐳\nGenerate any application with DeepSeek\nRunning\non\nZero\n325\n325\nICEdit\n🖼\nUniversal Image Editing is worth a single LoRA\nRunning\non\nZero\n1.18k\n1.18k\nDia 1.6B\n👯\nGenerate realistic dialogue from a script, using Dia!\nRunning\n440\n440\nQwen3 Demo\n📊\nGenerate responses to your messages\nRunning\non\nZero\n284\n284\nWaiNSFWIllustrious V110\n🖼\nGenerate images from textual prompts\nBrowse 400k+ applications\nDatasets\nnvidia/Nemotron-CrossThink\nUpdated\n6 days ago\n•\n2.27k\n•\n51\nrajpurkarlab/ReXGradient-160K\nUpdated\n1 day ago\n•\n460\n•\n39\nnvidia/OpenMathReasoning\nUpdated\n13 days ago\n•\n27.2k\n•\n178\nnvidia/OpenCodeReasoning\nUpdated\n2 days ago\n•\n17.4k\n•\n353\ndeepseek-ai/DeepSeek-ProverBench\nUpdated\n7 days ago\n•\n1.16k\n•\n24\nBrowse 250k+ datasets\nThe Home of Machine Learning\nCreate, discover and collaborate on ML better.\nThe collaboration platform\nHost and collaborate on unlimited public models, datasets and applications.\nMove faster\nWith the HF Open source stack.\nExplore all modalities\nText, image, video, audio or even 3D.\nBuild your portfolio\nShare your work with the world and build your ML profile.\nSign Up\nAccelerate your ML\nWe provide paid Compute and Enterprise solutions.\nCompute\nDeploy on optimized\nInference Endpoints\nor update your\nSpaces applications\nto a GPU in a few clicks.\nView pricing\nStarting at $0.60/hour for GPU\nEnterprise\nGive your team the most advanced platform to build AI with enterprise-grade security, access controls and\n\t\t\tdedicated support.\nGetting started\nStarting at $20/user/month\nSingle Sign-On\nRegions\nPriority Support\nAudit Logs\nResource Groups\nPrivate Datasets Viewer\nMore than 50,000 organizations are using Hugging Face\nAi2\nEnterprise\nnon-profit\n•\n756 models\n•\n3.21k followers\nAI at Meta\nEnterprise\ncompany\n•\n2.12k models\n•\n5.81k followers\nAmazon\ncompany\n•\n20 models\n•\n3.13k followers\nGoogle\ncompany\n•\n991 models\n•\n12.8k followers\nIntel\ncompany\n•\n220 models\n•\n2.51k followers\nMicrosoft\ncompany\n•\n374 models\n•\n12.1k followers\nGrammarly\nEnterprise\ncompany\n•\n10 models\n•\n157 followers\nWriter\nEnterprise\ncompany\n•\n21 models\n•\n266 followers\nOur Open Source\nWe are building the foundation of ML tooling with the community.\nTransformers\n143,933\nState-of-the-art ML for PyTorch, TensorFlow, JAX\nDiffusers\n28,876\nState-of-the-art Diffusion models in PyTorch\nSafetensors\n3,255\nSafe way to store/distribute neural network weights\nHub Python Library\n2,584\nPython client to interact with the Hugging Face Hub\nTokenizers\n9,659\nFast tokenizers optimized for research & production\nTRL\n13,609\nTrain transformers LMs with reinforcement learning\nTransformers.js\n13,554\nState-of-the-art ML running directly in your browser\nsmolagents\n18,069\nSmol library to build great agents in Python\nPEFT\n18,312\nParameter-efficient finetuning for large language models\nDatasets\n20,074\nAccess & share datasets for any ML tasks\nText ...

# %%
def create_brochure(company_name, url):
    response = openai.chat.completions.create(
        model=MODEL,
        messages=[
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": get_brochure_user_prompt(company_name, url)}
          ],
    )
    result = response.choices[0].message.content
    display(Markdown(result))

# %%
create_brochure("HuggingFace", "https://huggingface.co")
# Out:
# Found links: {'links': [{'type': 'about page', 'url': 'https://huggingface.co/huggingface'}, {'type': 'careers page', 'url': 'https://apply.workable.com/huggingface/'}, {'type': 'pricing page', 'url': 'https://huggingface.co/pricing'}, {'type': 'enterprise page', 'url': 'https://huggingface.co/enterprise'}, {'type': 'blog page', 'url': 'https://huggingface.co/blog'}]}
# # Hugging Face Brochure
#
# ---
#
# ## About Us
#
# ### The AI Community Building the Future
#
# At Hugging Face, we are dedicated to democratizing machine learning and making it accessible to everyone. We serve as a collaborative platform where individuals and organizations innovate, share, and improve upon models, datasets, and applications in the AI field.
#
# Our mission is clear: **to build a strong AI community together** and to develop the foundational tools for machine learning that can empower creators and organizations.
#
# ## Our Products
#
# ### Explore AI Apps and Models
#
# - **Models**: We host over **1 million models** spanning various applications, including text, image, and audio.
# - **Datasets**: With more than **250,000 datasets**, users can easily find resources suited for their machine learning tasks.
# - **Spaces**: A space for innovations where users can run applications with just a click.
#
# ### Enterprise Solutions
#
# Hugging Face provides enterprise-grade solutions to assist businesses in building robust AI with added security and dedicated support.
#
# - **Compute Solutions**: Starting at $0.60/hour for GPU.
# - **Enterprise Packages**: Available from $20/user/month featuring Single Sign-On, priority support, and more.
#
# ## Our Culture
#
# ### Inclusivity & Collaboration
#
# At Hugging Face, we foster a culture of inclusivity where every voice is valued. We believe in creating a space where ideas can flourish and collaborations can happen seamlessly. With an active community of over **50,000 organizations**, we share a common goal to enhance machine learning applications and tools.
#
# ### Continuous Learning
#
# We encourage our team to engage with our community through documentation, studies, and public collaboration. Our culture emphasizes learning from each other, sharing expertise, and building innovative solutions together.
#
# ## Who We Serve
#
# ### Trust of Leading Organizations
#
# More than **50,000 organizations**, including industry pioneers like Google, Microsoft, and Amazon, leverage our platform for their machine learning needs. Our proactive engagement with top-tier companies reinforces our commitment to excellence in technology development.
#
# ## Careers at Hugging Face
#
# Join a vibrant team that is pushing the boundaries of AI. We are looking for passionate individuals who thrive in a collaborative environment. Check out our open positions and be part of a movement to make machine learning better for everyone.
#
# - [Explore Jobs at Hugging Face](https://huggingface.co/jobs)
#
# ---
#
# ### Connect with Us
#
# Join us on our mission to democratize machine learning! For more information, support, or to contribute, visit our website or connect with us on social platforms:
#
# - [Website](https://huggingface.co)
# - [GitHub](https://github.com/huggingface)
# - [Twitter](https://twitter.com/huggingface)
# - [LinkedIn](https://linkedin.com/company/huggingface)
# - [Discord](https://discord.gg/huggingface)
#
# ---
#
# **Hugging Face** - Together, let's build the future of AI!

# %% [markdown]
# ## Finally - a minor improvement
#
# With a small adjustment, we can change this so that the results stream back from OpenAI,
# with the familiar typewriter animation

# %%
def stream_brochure(company_name, url):
    stream = openai.chat.completions.create(
        model=MODEL,
        messages=[
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": get_brochure_user_prompt(company_name, url)}
          ],
        stream=True
    )
    
    response = ""
    display_handle = display(Markdown(""), display_id=True)
    for chunk in stream:
        response += chunk.choices[0].delta.content or ''
        response = response.replace("```","").replace("markdown", "")
        update_display(Markdown(response), display_id=display_handle.display_id)

# %%
stream_brochure("HuggingFace", "https://huggingface.co")
# Out:
# Found links: {'links': [{'type': 'about page', 'url': 'https://huggingface.co/huggingface'}, {'type': 'careers page', 'url': 'https://apply.workable.com/huggingface/'}, {'type': 'enterprise page', 'url': 'https://huggingface.co/enterprise'}, {'type': 'pricing page', 'url': 'https://huggingface.co/pricing'}, {'type': 'blog page', 'url': 'https://huggingface.co/blog'}, {'type': 'community forum', 'url': 'https://discuss.huggingface.co'}, {'type': 'GitHub page', 'url': 'https://github.com/huggingface'}, {'type': 'Twitter page', 'url': 'https://twitter.com/huggingface'}, {'type': 'LinkedIn page', 'url': 'https://www.linkedin.com/company/huggingface/'}]}
# # Hugging Face Brochure
#
# ## Welcome to Hugging Face
# **The AI community building the future.** Hugging Face is a collaborative platform for the machine learning community, enabling members to discover, share, and build upon models, datasets, and applications to drive the future of AI.
#
# ---
#
# ### Our Mission
# At Hugging Face, we are committed to democratizing machine learning. Our goal is to create an inclusive environment where anyone, from hobbyists to enterprise teams, can access state-of-the-art tools and technologies for AI development.
#
# ---
#
# ### Company Culture
# - **Collaborative Spirit:** We take pride in fostering a community-driven platform where collaboration is at the core of what we do. Everyone's contributions are valued, and the collective knowledge drives innovation in the field of machine learning.
#
# - **Open Source Ethos:** Hugging Face places a strong emphasis on open-source development. We believe in the importance of sharing our technology and tools for the greater good of the AI and ML community.
#
# - **Diversity & Inclusion:** Our diverse workforce and inclusive culture are foundational principles at Hugging Face. We support varied backgrounds and perspectives, leading to richer ideas and solutions.
#
# ---
#
# ### Who We Serve
# More than **50,000 organizations**, including major players like:
#
# - **Meta**
# - **Amazon**
# - **Google**
# - **Microsoft**
# - **Intel**
#
# Join companies across various industries who rely on Hugging Face's leading models and datasets.
#
# ---
#
# ### What We Offer
# - **1M+ Models:** Browse and collaborate on an extensive library of machine learning models tailored for various applications.
#
# - **250k+ Datasets:** Access a wide range of datasets suitable for any ML tasks.
#
# - **Spaces:** Create and run applications with ease, enabling fast prototyping and deployment.
#
# - **Enterprise Solutions:** We provide enterprise-grade tools with security, dedicated support, and easy access controls tailored for teams.
#
# ---
#
# ### Careers at Hugging Face
# We are continually looking for passionate individuals to join our team. Whether you’re a developer, researcher, or community advocate, there are numerous opportunities to contribute to meaningful projects in the AI space.
#
# Why work with us?
# - **Innovative Environment:** Work on cutting-edge AI technologies and collaborate with experts in the field.
# - **Growth & Learning:** We encourage continuous learning and professional development, offering resources to help you grow in your career.
# - **Flexible Work Options:** Embracing remote work options while supporting a healthy work-life balance.
#
# ---
#
# ### Join Our Community
# Explore our [website](https://huggingface.co) to sign up today, engage in discussions, and contribute your ideas to shape the future of AI. Together, let’s build and inspire the next generation of machine learning technology!
#
# ---
#
# **Connect with us:**
# - [GitHub](https://github.com/huggingface)
# - [Twitter](https://twitter.com/huggingface)
# - [LinkedIn](https://linkedin.com/company/huggingface)
# - [Discord](https://discord.gg/huggingface)
#
# ---
#
# **Hugging Face: Empowering the AI community for a smarter future.**

# %%
# Try changing the system prompt to the humorous version when you make the Brochure for Hugging Face:

stream_brochure("HuggingFace", "https://huggingface.co")

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../business.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#181;">Business applications</h2>
#             <span style="color:#181;">In this exercise we extended the Day 1 code to make multiple LLM calls, and generate a document.
#
# This is perhaps the first example of Agentic AI design patterns, as we combined multiple calls to LLMs. This will feature more in Week 2, and then we will return to Agentic AI in a big way in Week 8 when we build a fully autonomous Agent solution.
#
# Generating content in this way is one of the very most common Use Cases. As with summarization, this can be applied to any business vertical. Write marketing content, generate a product tutorial from a spec, create personalized email content, and so much more. Explore how you can apply content generation to your business, and try making yourself a proof-of-concept prototype. See what other students have done in the community-contributions folder -- so many valuable projects -- it's wild!</span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#900;">Before you move to Week 2 (which is tons of fun)</h2>
#             <span style="color:#900;">Please see the week1 EXERCISE notebook for your challenge for the end of week 1. This will give you some essential practice working with Frontier APIs, and prepare you well for Week 2.</span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../resources.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#f71;">A reminder on 3 useful resources</h2>
#             <span style="color:#f71;">1. The resources for the course are available <a href="https://edwarddonner.com/2024/11/13/llm-engineering-resources/">here.</a><br/>
#             2. I'm on LinkedIn <a href="https://www.linkedin.com/in/eddonner/">here</a> and I love connecting with people taking the course!<br/>
#             3. I'm trying out X/Twitter and I'm at <a href="https://x.com/edwarddonner">@edwarddonner<a> and hoping people will teach me how it's done..
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../thankyou.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#090;">Finally! I have a special request for you</h2>
#             <span style="color:#090;">
#                 My editor tells me that it makes a MASSIVE difference when students rate this course on Udemy - it's one of the main ways that Udemy decides whether to show it to others. If you're able to take a minute to rate this, I'd be so very grateful! And regardless - always please reach out to me at ed@edwarddonner.com if I can help at any point.
#             </span>
#         </td>
#     </tr>
# </table>
